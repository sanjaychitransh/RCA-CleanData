# %%
# Import libraries
#!pip install openpyxl --upgrade
import pandas as pd
import re
import ollama
import numpy as np

# %%
# Read cleam data in processed_text and create a DataFrame
df = pd.read_csv("clean_data_with_processed_text.csv")  
df['processed_text']=df['processed_text'].apply(str)

df.head()
# Out:
#   Case: Case Number                                      Case: Subject  \
# 0       TS017525407  Email - We required high uninitialized Luns/ho...
# 1       TS017538910                                      SWITCH REBOOT
# 2       TS017505135  Email-LUN Total Latency is greater than or equ...
# 3       TS017519459               Expired Certificates (EXPIRED_CERTS)
# 4       TS017504642               Email - Need to change the SFP fault
#
#                                    Case: Description     Case: Product Name  \
# 0  We required high uninitialized Luns/hosts (Hig...                DS8900F
# 1  2 reboot events "Non restartable component (fd...  SAN b-type Collection
# 2  LUN Total Latency is greater than or equal to ...       FlashSystem 9200
# 3  Good afternoon, we recently received several w...  SAN b-type Collection
# 4                             Need to change the SFP  SAN c-type Collection
#
#   Automation Item Name Created Date  \
# 0           AI-1560218   2024-10-14
# 1           AI-1561615   2024-10-14
# 2           AI-1562015   2024-10-14
# 3           AI-1562168   2024-10-14
# 4           AI-1562711   2024-10-14
#
#                                                 Body Feedback  \
# 0  Customer Sentiment Not available Description S...     None
# 1  Customer Sentiment neutral Description Summary...     None
# 2  Customer Sentiment Not available Description S...     None
# 3  Customer Sentiment neutral Description Summary...     None
# 4  Customer Sentiment neutral Description Summary...     None
#
#                       Detailed Feedback    Case: Status  \
# 0                                  good   Closed by IBM
# 1                                    ok   Closed by IBM
# 2  Very useful feather to have , thanks  IBM is working
# 3                                    ok   Closed by IBM
# 4                                    ok   Closed by IBM
#
#    Case: Client Escalated                                     processed_text
# 0                       0  customer sentiment available description summa...
# 1                       0  customer sentiment neutral description summary...
# 2                       0  customer sentiment available description summa...
# 3                       0  customer sentiment neutral description summary...
# 4                       0  customer sentiment neutral description summary...

# %%
from functools import wraps
import shelve
import hashlib

def cached(func):
    func.cache = shelve.open('llm_cache_CleanData')
    @wraps(func)
    def wrapper(*args):
        h = hashlib.sha512(str(args).encode('utf-8')).hexdigest()
        try:
            return func.cache[h]
        except KeyError:
            func.cache[h] = result = func(*args)
            func.cache.close()
            func.cache = shelve.open('llm_cache_CleanData')
            return result
    return wrapper

# %%
# Process case summaries with LLM
@cached
def get_RCA_from_LLM(context, prompt, model):
#The RCA must at least contain the root cause, analysis, resolution, and impact.
    response = ollama.chat(
        model=model,
        messages=[{
            'role': 'user',
            'content': prompt + context
        }]
    )
    return response['message']['content']

# Loop through cases and generate RCA
prompt = """
Here is an example of an RCA:
{
  "RCA": {
    "incident_id": "",
    "date": "",
    "problem": {
      "description": "Memory leak causing service degradation in Service C",
      "symptoms": "Service C experienced gradual performance degradation over 3 hours.",
      "detected_by": "Monitoring system - High memory usage alert"
    },
    "root_cause": {
      "description": "Improper memory management in the data processing module.",
      "related_services": ["Service A", "Service B"],
      "historical_pattern": "Similar memory leak issues found in Service A (Jan 2021) and Service B (Mar 2022)."
    },
    "resolution": {
      "description": "Applied memory optimization techniques, including better memory allocation strategies and garbage collection triggers.",
      "steps_taken": [
        "Identified the memory leak using memory profiler tools.",
        "Optimized memory usage in the data processing module.",
        "Tested the fix in a controlled environment."
      ],
      "time_to_resolve": "2 hours",
      "service_downtime": "3 hours",
      "service_restoration": "Full service restored after memory optimization."
    },
    "impact": {
      "description": "Service degradation for 3 hours, impacting 15% of users.",
      "business_impact": "Moderate performance issues, leading to delays in processing large files."
    },
    "preventive_actions": {
      "description": "Implemented proactive memory monitoring and automated garbage collection.",
      "actions": [
        "Added memory usage alerts in the monitoring system.",
        "Conducted code review to improve memory handling in related services."
      ],
      "future_risk": "High likelihood of similar issues in Service D due to similar code structure."
    }
  }
}
Assume the role of an SRE engineer and give me an RCA report based on the following summary.
Return the report in json format.
If you don't have the data or it's unclear return an empty string :\n
"""
RCA = []
model='granite3-dense:8b-instruct-fp16'
for i, row in df.iterrows():
    context = 'ID: '+row['Case: Case Number']+"\n"    
    context += 'Subject: '+row['Case: Subject']+"\n" 
    context += 'Description: '+row['Case: Description']+"\n" 
    context += 'Created Date: '+str(row['Created Date'])+"\n" 
    context += 'Summary: '+row['processed_text']+"\n"
    print(context)
    RCA += [get_RCA_from_LLM(context, prompt, model)]
    if i > 5: break
# Out:
# ID: TS017525407
# Subject: Email - We required high uninitialized Luns/hosts (High workload) and any hardware issues observed at storage end
# Description: We required high uninitialized Luns/hosts (High workload) and any hardware issues observed at storage end
# Created Date: 2024-10-14
# Summary: customer sentiment available description summary summarized email required high uninitialized high workload hardware issue observed storage end required high uninitialized high workload hardware issue observed storage end feed summary summary icici bank requested assistance high uninitialized potential hardware issue storage system ibm support requested information high uninitialized observed hardware issue icici bank provided time frame issue confirmed open event hardware issue time also requested information consuming high load specified time stamp ibm support recommended bandwidth study existing dark fiber link colo site configuration spectrum control monitoring software send report host workload metric ibm expert lab team conduct bandwidth study configure spectrum control reporting ibm support also requested spectrum control report time frame hr storage system icici bank later provided spectrum control report two storage system requested analysis ibm support analyzed report provided table replication bandwidth system specified time stamp maximum combined send replication bandwidth two system exceed maximum send replication bandwidth third system exceed ibm support also noted san congestion metro mirror port three system could impact write latency host application recommended engaging san support team analyze buffer starvation issue metro mirror port engaging link vendor optimize link latency icici bank later requested information session running specified time frame ibm support noted session related information available spectrum control performance package resolution summary confirmed solution generated watsonx maximum combined send replication bandwidth system mibps link throughput dc site colo site exceed problem timestamps maximum send replication bandwidth system mibps link throughput colo site dc site exceed problem timestamps however san congestion metro mirror port system impact write latency host application recommendation resolve issue include engaging san support team analyze buffer starvation issue metro mirror port engaging link vendor optimize link latency close possible action recommended system solution attempt generated watsonx hardware analysis show storage system operating optimal status specified problem window hardware issue lead performance problem support team requested information including clarification meant high uninitialized list affected system detail impact application due reported performance problem also asked observation database o perspective
#
# ID: TS017538910
# Subject: SWITCH REBOOT
# Description: 2 reboot events "Non restartable component (fdmi (pid=1207)) died"
# Created Date: 2024-10-14
# Summary: customer sentiment neutral description summary summarized switch reboot reboot event non restartable component fdmi died feed summary subject switch reboot description reboot event error message non restartable component fdmi resolution summary confirmed solution generated watsonx probable cause indicates software watchdog detected termination restartable daemon need restart initiate failover recommended action execute reboot command restart system initiate failover using hafailover command recommendation please hareboot hafailover bigger switch director blade fix issue solution attempt summarized
#
# ID: TS017505135
# Subject: Email-LUN Total Latency is greater than or equal to 20ms
# Description: LUN Total Latency is greater than or equal to 20ms
# Created Date: 2024-10-14
# Summary: customer sentiment available description summary summarized total latency greater equal lun total latency greater equal feed summary customer reported issue high latency specific host volume customer asked provide information including timeframe impact issue customer provided list volume host specific timeframe impact detail customer reminded performance investigation typically done system eos firmware support team agreed help within reason support team requested snap log customer receive response customer later submitted log contain useful information timeframe question support team requested new log snap timeframe issue receive response case assigned global support team assistance resolution summary confirmed solution summarized solution attempt summarized reply
#
# ID: TS017519459
# Subject: Expired Certificates (EXPIRED_CERTS)
# Description: Good afternoon, we recently received several warnings through SAN-NAV: Rule Name C_EC_G0_N_x_RTxxxx Rule Condition CHASSIS(EXPIRED_CERTS/NONE>0) Severity Warning Switch Severity Warning Measure Value 2 Actions RAS Log Event,SNMP Trap Questions ======== What kind of license it refers at? What steps do we have to take? If is a new license, where do we can to get it? Thanks in advance
# Created Date: 2024-10-14
# Summary: customer sentiment neutral description summary summarized expired certificate good afternoon recently received several warning rule name rule condition chassis severity warning switch severity warning measure value action ra log event snmp trap question kind license refers step take new license get thanks advance feed summary customer reported warning regarding expired certificate ibm support requested log detail asset analyzing log ibm support determined certificate switch expired switch detected expired certificate sannav ibm support provided instruction customer check expired certificate sannav continue monitor new appearance error case put hold week customer advised check sannav provide output command seccertmgmt show kafka determine validity kafka certificate ibm support provided instruction renewing kafka certificate continue work customer implement renewal procedure resolution summary confirmed solution summarized sent message mailbox procedure kafka renewal solution attempt summarized
#
# ID: TS017504642
# Subject: Email - Need to change the SFP fault
# Description: Need to change the SFP
# Created Date: 2024-10-14
# Summary: customer sentiment neutral description summary summarized email need change sfp fault need change sfp feed summary customer requested assistance changing sfp small pluggable san storage area network switch customer provided port number resolution summary confirmed solution generated watsonx please check sfp hba remote side port good please replace cable port order revive link please send u new log check solution attempt summarized
#
# ID: TS017578100
# Subject: VIOS and Power OS and firmware life cycle level confirmations
# Description: Submitting this case to get confirmation on the current end of lifecycle for VIO and server firmware levels on Power 9 and power 10. I tried searching IBM technotes for confirmation on what levels are supported, but was unable to find anything specific or that confirmed what I was looking for. Please let me know
# Created Date: 2024-10-14
# Summary: customer sentiment neutral description summary customer seeking confirmation current eol level vios power o firmware power power system unable find information ibm technotes feed summary customer requested confirmation current end lifecycle vios product server firmware level power power resolution summary confirmed solution summarized solution attempt generated watsonx service request routed powervm vios support taken ownership case remain opened oct opened separate service request behalf hardware support assist server firmware level power power new case refer following url detail lifecycle vios product
#
# ID: TS017167652
# Subject: KPIBDCP11FS9006 : Node warmstarted due to an internal error
# Description: Date: 07/09/2024 Summary: tsveETrap: tsve error trap Severity: 3 ResourceId: 10.15.116.55 ServerSerial: 17910352 ServerName: NCO_PRI CustomerCode: kp1 InstanceId: Generic(6) Specific(1) Service: staas-bld AlertKey: # Machine Type = 9846AG8# Serial Number = 78E3638 # Error ID = 74002 : Node warmstarted due to an internal error# Error Code = 2030 : Internal error# System Version = 8.5.0.9 (build 157.15.2306271144000) # FRU = None # System Name = KPIBDCP11FS9006# Node ID NodeAlias: 10.15.116.55 node got warmstarted , please check.
# Created Date: 2024-10-14
# Summary: customer sentiment neutral description summary internal error occurred node causing warmstart error indicated tsve error trap error code system version build fru identified issue customer check status node feed summary node storage system serial number machine type experienced internal error warmstarted error caused rare race condition triggered multiple abort io issue issue addressed apar fixed customer planning upgrade instead customer also experiencing issue sfp fru requested replacement work order submitted part delivered data center customer also requested po part determined po needed customer retain part case closed resolution summary confirmed solution summarized solution attempt summarized greeting ibm technical analysis node topology standard id panelid fileid name type iogid iogname status version online config node online svc cluster version build svc upgrade status inactive event node node assert unfixed snmp error node assert assert file line node asserted assert string line node asserted suggests pool free object however object available free list underneath caused rare race condition triggered multiple abort io issue issue addressed apar fixed

# %%
# Print Sample RCA
i = 0
print('Original Summary: ',df['processed_text'][i])
print('RCA:', RCA[i])
# Out:
# Original Summary:  customer sentiment available description summary summarized email required high uninitialized high workload hardware issue observed storage end required high uninitialized high workload hardware issue observed storage end feed summary summary icici bank requested assistance high uninitialized potential hardware issue storage system ibm support requested information high uninitialized observed hardware issue icici bank provided time frame issue confirmed open event hardware issue time also requested information consuming high load specified time stamp ibm support recommended bandwidth study existing dark fiber link colo site configuration spectrum control monitoring software send report host workload metric ibm expert lab team conduct bandwidth study configure spectrum control reporting ibm support also requested spectrum control report time frame hr storage system icici bank later provided spectrum control report two storage system requested analysis ibm support analyzed report provided table replication bandwidth system specified time stamp maximum combined send replication bandwidth two system exceed maximum send replication bandwidth third system exceed ibm support also noted san congestion metro mirror port three system could impact write latency host application recommended engaging san support team analyze buffer starvation issue metro mirror port engaging link vendor optimize link latency icici bank later requested information session running specified time frame ibm support noted session related information available spectrum control performance package resolution summary confirmed solution generated watsonx maximum combined send replication bandwidth system mibps link throughput dc site colo site exceed problem timestamps maximum send replication bandwidth system mibps link throughput colo site dc site exceed problem timestamps however san congestion metro mirror port system impact write latency host application recommendation resolve issue include engaging san support team analyze buffer starvation issue metro mirror port engaging link vendor optimize link latency close possible action recommended system solution attempt generated watsonx hardware analysis show storage system operating optimal status specified problem window hardware issue lead performance problem support team requested information including clarification meant high uninitialized list affected system detail impact application due reported performance problem also asked observation database o perspective
# RCA: {
#   "RCA": {
#     "incident_id": "TS017525407",
#     "date": "2024-10-14",
#     "problem": {
#       "description": "High workload and potential hardware issues observed in the storage system",
#       "symptoms": "Customer reported high uninitialized Luns/hosts, high workload, and potential hardware issues at the storage end.",
#       "detected_by": "IBM Support"
#     },
#     "root_cause": {
#       "description": "Excessive replication bandwidth and SAN congestion leading to performance degradation",
#       "related_services": ["Storage system"],
#       "historical_pattern": "No historical pattern provided."
#     },
#     "resolution": {
#       "description": "Bandwidth study, configuration of Spectrum Control, and engagement with San support team",
#       "steps_taken": [
#         "Conducted a bandwidth study using IBM Expert Lab team.",
#         "Configured Spectrum Control for monitoring and reporting.",
#         "Engaged with the San support team to analyze buffer starvation issue and optimize link latency.",
#         "Generated a solution using WatsonX."
#       ],
#       "time_to_resolve": "Not specified",
#       "service_downtime": "Not specified",
#       "service_restoration": "Service restored after implementing the recommended solutions."
#     },
#     "impact": {
#       "description": "Performance degradation and potential impact on write latency for host applications",
#       "business_impact": "Potential impact on application performance due to high workload and hardware issues."
#     },
#     "preventive_actions": {
#       "description": "Engage with San support team and optimize link latency",
#       "actions": [
#         "Analyze buffer starvation issue and optimize link latency with the San support team.",
#         "Optimize link latency by engaging with the link vendor."
#       ],
#       "future_risk": "High likelihood of similar issues if not addressed proactively."
#     }
#   }
# }

# %%
#classinfication of the data :LLM classoify in RCA,Example, to do list pending

# %%
from qdrant_client import QdrantClient, models

client = QdrantClient(url="http://localhost:6333")

client.create_collection(
    collection_name="{rca_collection_CleanData}",
    vectors_config=models.VectorParams(size=100, distance=models.Distance.COSINE),
)
# Out:
# True

# %%
# Create a collection
# Add RCAs to vector database
idx = client.add(
    collection_name="rca_collection_CleanData",
    documents=RCA
)

# %%
# Search RCA dataset

# query = "firewall issue"
query = "a faulty drive was detected"

search_result = client.query(
    collection_name="rca_collection_CleanData",
    query_text=query
)

# Print TOP 3 results
for i, r in enumerate(search_result):
    print('score:', r.score)
    print(r.metadata['document'])
    if i+1 >= 3: break
# Out:
# score: 0.8731602
# {
#   "RCA": {
#     "incident_id": "TS017538910",
#     "date": "2024-10-14",
#     "problem": {
#       "description": "Switch reboot due to non-restartable component (fdmi) dying",
#       "symptoms": "Two reboot events occurred with the error message 'Non restartable component (fdmi (pid=1207)) died'",
#       "detected_by": "Watsonx"
#     },
#     "root_cause": {
#       "description": "Software watchdog detected termination of restartable daemon, causing the need for a system reboot and failover",
#       "related_services": ["Switch"],
#       "historical_pattern": "No similar incidents found in the past."
#     },
#     "resolution": {
#       "description": "Restarted the system using the reboot command and initiated failover using the hafailover command",
#       "steps_taken": [
#         "Confirmed the solution using Watsonx.",
#         "Generated a probable cause indicating software watchdog detected termination of restartable daemon.",
#         "Recommended executing the reboot command and initiating failover using the hafailover command."
#       ],
#       "time_to_resolve": "Not specified",
#       "service_downtime": "Not specified",
#       "service_restoration": "System restored after restarting and initiating failover."
#     },
#     "impact": {
#       "description": "Switch reboot causing potential service disruption",
#       "business_impact": "Potential impact on customer services, but no specific business impact mentioned."
#     },
#     "preventive_actions": {
#       "description": "No preventive actions specified in the summary.",
#       "actions": [],
#       "future_risk": "Low likelihood of similar issues in the future, as no historical pattern was found."
#     }
#   }
# }
# score: 0.85677415
# {
#   "RCA": {
#     "incident_id": "TS017504642",
#     "date": "2024-10-14",
#     "problem": {
#       "description": "SFP fault in SAN storage area network switch",
#       "symptoms": "Customer reported the need to change the SFP due to a fault.",
#       "detected_by": "Customer request for assistance"
#     },
#     "root_cause": {
#       "description": "Faulty SFP module causing connectivity issues in the SAN switch.",
#       "related_services": ["SAN storage area network switch"],
#       "historical_pattern": "No historical pattern found."
#     },
#     "resolution": {
#       "description": "Replaced the faulty SFP module and checked the cable connection.",
#       "steps_taken": [
#         "Confirmed the issue was with the SFP module.",
#         "Replaced the faulty SFP module with a new one.",
#         "Checked the cable connection and ensured it was secure."
#       ],
#       "time_to_resolve": "1 hour",
#       "service_downtime": "No service downtime reported.",
#       "service_restoration": "Full service restored after replacing the faulty SFP module."
#     },
#     "impact": {
#       "description": "No impact on customer operations due to quick resolution.",
#       "business_impact": "Minimal business impact, as the issue was resolved promptly."
#     },
#     "preventive_actions": {
#       "description": "Regularly inspect and maintain SFP modules in SAN switches.",
#       "actions": [
#         "Schedule periodic checks of SFP modules in SAN switches.",
#         "Maintain a spare inventory of SFP modules for quick replacements."
#       ],
#       "future_risk": "Low likelihood of similar issues if regular maintenance is performed."
#     }
#   }
# }
# score: 0.85332114
# {
#   "RCA": {
#     "incident_id": "TS017167652",
#     "date": "2024-10-14",
#     "problem": {
#       "description": "Node warmstarted due to an internal error causing tsve error trap",
#       "symptoms": "Node got warmstarted, triggered multiple abort I/O issues.",
#       "detected_by": "tsve error trap"
#     },
#     "root_cause": {
#       "description": "Rare race condition triggered by multiple abort I/O issues due to object availability in free list underneath",
#       "related_services": ["staas-bld"],
#       "historical_pattern": "No similar incidents found in the past."
#     },
#     "resolution": {
#       "description": "APAR fixed, customer planning upgrade instead",
#       "steps_taken": [
#         "Confirmed solution summarized",
#         "SFP FRU requested replacement",
#         "Work order submitted, part delivered"
#       ],
#       "time_to_resolve": "Not specified",
#       "service_downtime": "Not specified",
#       "service_restoration": "Not specified"
#     },
#     "impact": {
#       "description": "Internal error causing node warmstart and multiple abort I/O issues",
#       "business_impact": "Potential data loss and service disruption."
#     },
#     "preventive_actions": {
#       "description": "Implement additional error handling and monitoring",
#       "actions": [
#         "Review and update error handling mechanisms",
#         "Implement additional monitoring for rare race conditions"
#       ],
#       "future_risk": "Low likelihood of similar issues in the future with improved error handling and monitoring."
#     }
#   }
# }
